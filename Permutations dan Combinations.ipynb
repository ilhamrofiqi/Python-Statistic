# %% [markdown]
# # Permutations (Permutasi)
# Permutasi menghitung banyaknya cara menyusun suatu kumpulan objek dengan memperhatikan urutan.
#
# Rumus:
#
# ![image.png](attachment:1cb126b6-2bd5-4f12-bc75-3e10ecc2479b.png)
#
# 𝑛: jumlah total objek
#
# 𝑟: jumlah objek yang disusun
#
# !: simbol faktorial (misalnya, 5!=5×4×3×2×1).
#
# ### Contoh
# ![image.png](attachment:10d5760b-dc25-4311-a7aa-ac1bd843a125.png)

# %% [markdown]
# # Combinations (Kombinasi)
#
# Kombinasi menghitung banyaknya cara memilih objek dari suatu kumpulan tanpa memperhatikan urutan.
#
# Rumus:
#
# ![image.png](attachment:8e1e3448-efb0-4dba-b3f0-d2b72878127d.png)
#
# 𝑛: jumlah total objek
#
# 𝑟: jumlah objek yang dipilih
#
# ### Contoh:
# ![image.png](attachment:0fe55fee-b55f-4e09-9320-c7e00fba9f2f.png)
